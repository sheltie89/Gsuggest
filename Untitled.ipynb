# %%
import GoogleSuggest as gs

# %%
#input keyword
phrase = 'python'

# get Google Suggest result (keyword + XX)
searcher = gs.GoogleSuggestClass()
result = searcher.get_suggest_keyword(phrase);
# Out:
# Search Result: [python]
#   python
#   python 入門
#   python if
#   python インストール
#   python for
#   python for文
#   python 配列
#   python print
#   python range
#   python split
# Search Result: [python ]
#   python 入門
#   python if
#   python インストール
#   python for
#   python for文
#   python 配列
#   python print
#   python range
#   python split
#   python 資格
# Search Result: [python あ]
#   python アンインストール
#   python アルバイト
#   python あまり
#   python アプリ開発
#   python アップデート
#   python アプリ
#   python アニメーション
#   python アスタリスク
#   python アットマーク
#   python 暗号化
# Search Result: [python い]
#   python インストール
#   python インクリメント
#   python 意味
#   python インデント
#   python インストール windows10
#   python インタプリタ
#   python イテレータ
#   python インストール mac
#   python インスタンス
#   python インスタンス変数
# Search Result: [python う]
#   python ウェブサイト
#   python うるう年
#   python ウェブスクレイピング
#   python ウィンドウ作成
#   python ウェブ
#   python ウィンドウ操作
#   python ウィンドウ 表示
#   python 動かし方
#   python 動かない
#   python ウェブサイト 作成
# ...

# %%
print(result)
# Out:
# ['python', 'python 入門', 'python if', 'python インストール', 'python for', 'python for文', 'python 配列', 'python print', 'python range', 'python split', 'python 資格', 'python アンインストール', 'python アルバイト', 'python あまり', 'python アプリ開発', 'python アップデート', 'python アプリ', 'python アニメーション', 'python アスタリスク', 'python アットマーク', 'python 暗号化', 'python インクリメント', 'python 意味', 'python インデント', 'python インストール windows10', 'python インタプリタ', 'python イテレータ', 'python インストール mac', 'python インスタンス', 'python インスタンス変数', 'python ウェブサイト', 'python うるう年', 'python ウェブスクレイピング', 'python ウィンドウ作成', 'python ウェブ', 'python ウィンドウ操作', 'python ウィンドウ 表示', 'python 動かし方', 'python 動かない', 'python ウェブサイト 作成', 'python 演算子', 'python エクセル', 'python エラー処理', 'python エディタ', 'python エクセル 読み込み', 'python 演習', 'python エンジニア認定試験', 'python エラー', 'python エスケープシーケンス', 'python 円周率', 'python オブジェクト指向', 'python 大文字 小文字', 'python 音を鳴らす', 'python オブジェクト', 'python オーバーロード', 'python オプション m', 'python オーバーライド', 'python 折れ線グラフ', 'python おすすめ 本', 'python 遅い', 'python 関数
# ...
